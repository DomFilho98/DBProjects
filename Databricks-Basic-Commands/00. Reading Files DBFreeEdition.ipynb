# %%
# %fs
ls dbfs:/databricks-datasets/

# %%
# %fs
ls 'dbfs:/databricks-datasets/retail-org/'

# %%
# %fs
ls 'dbfs:/databricks-datasets/retail-org/products/'

# %%
df_products = 'dbfs:/databricks-datasets/retail-org/products/products.csv'

df = spark.read.format('csv')\
.option('header', 'true')\
.option('inferSchema', 'true')\
.option('delimiter',';')\
.load(df_products)

display(df)

# %%
# %python

# %fs
ls '/Volumes/workspace/default/classfiles'

# %%
# %fs
ls 'dbfs:/Volumes/workspace/default/classfiles/arquivos_csv/'

# %%
df_products = 'dbfs:/Volumes/workspace/default/classfiles/arquivos_csv/Clientes.csv'

df = spark.read.format('csv')\
.option('header', 'true')\
.option('inferSchema', 'true')\
.option('delimiter',',')\
.load(df_products)

display(df)
